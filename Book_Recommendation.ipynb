# %% [markdown]
# # Project 554– Recommendation system

# %% [markdown]
# # Objective
# Build a book recommendation system using the provided datasets "Users", "Books", and "Ratings". The system should generate features from the data and recommend books to users. The final model should be deployed using RShiny, Flask, or Streamlit.

# %% [markdown]
# ## Data loading
#
# Load the three datasets (Users, Books, and Ratings) into pandas DataFrames.

# %%
import pandas as pd

users_df = pd.read_csv('Users.csv',encoding='ISO-8859-1')
books_df = pd.read_csv('Books.csv',encoding='ISO-8859-1')
ratings_df = pd.read_csv('Ratings.csv',encoding='ISO-8859-1')

print("Users DataFrame head:")
display(users_df.head())
print("\nBooks DataFrame head:")
display(books_df.head())
print("\nRatings DataFrame head:")
display(ratings_df.head())
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_27564\4135568699.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv('Books.csv',encoding='ISO-8859-1')
# Users DataFrame head:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN
# Books DataFrame head:
#         ISBN                                         Book-Title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
# Ratings DataFrame head:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726   155061224            5
# 2   276727   446520802            0
# 3   276729  052165615X            3
# 4   276729   521795028            6

# %% [markdown]
# ## Data exploration and preprocessing
#
#
# Exploring each dataset to understand its structure, identify missing values, and analyze data types. Handle missing values in the Users dataset (location and age) and analyze the distribution of ratings and decide how to handle explicit (1-10) and implicit (0) ratings, this will let us take the potential data cleaning steps like removing duplicate entries or handling inconsistent data.

# %% [markdown]
# Lets print the concise summary of each dataframe and check for missing values in `users_df`, and examine the unique values and their counts in the 'Age' column of `users_df`.

# %%
print("Users DataFrame summary:")
users_df.info()

print("\nBooks DataFrame summary:")
books_df.info()

print("\nRatings DataFrame summary:")
ratings_df.info()

print("\nMissing values in Users DataFrame:")
display(users_df.isnull().sum())

print("\nUnique values and counts in 'Age' column of Users DataFrame:")
display(users_df['Age'].value_counts(dropna=False).sort_index())
# Out:
# Users DataFrame summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB
#
# Books DataFrame summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB
#
# Ratings DataFrame summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1048575 non-null  int64
#  1   ISBN         1048575 non-null  object
#  2   Book-Rating  1048575 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB
#
# Missing values in Users DataFrame:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64
# Unique values and counts in 'Age' column of Users DataFrame:
# Age
# 0.0         416
# 1.0         288
# 2.0         105
# 3.0          45
# 4.0          28
#           ...
# 231.0         1
# 237.0         1
# 239.0         1
# 244.0         1
# NaN      110762
# Name: count, Length: 166, dtype: int64

# %% [markdown]
# Analyze the distribution of book ratings, handle age outliers , handle missing age values in `users_df` by replacing values above 90 and below 5 with NaN and then imputing NaN with the median, and handle implicit ratings in `ratings_df` by removing them.

# %%
import numpy as np

print("\nValue counts of 'Book-Rating' column in Ratings DataFrame:")
display(ratings_df['Book-Rating'].value_counts().sort_index())

# Handle missing age values in users_df
users_df['Age'] = users_df['Age'].apply(lambda x: np.nan if x > 90 or x < 5 else x)


users_df['Age'] = users_df['Age'].fillna(users_df['Age'].median())


print("\nMissing values in Users DataFrame after handling Age:")
display(users_df.isnull().sum())

# Handle implicit ratings in ratings_df
ratings_df = ratings_df[ratings_df['Book-Rating'] != 0]
print("\nRatings DataFrame after removing implicit ratings:")
display(ratings_df.head())
# Out:
# Value counts of 'Book-Rating' column in Ratings DataFrame:
# Book-Rating
# 0     651330
# 1       1601
# 2       2492
# 3       5445
# 4       8031
# 5      46953
# 6      33753
# 7      70018
# 8      95037
# 9      62101
# 10     71814
# Name: count, dtype: int64
# Missing values in Users DataFrame after handling Age:
# User-ID     0
# Location    0
# Age         0
# dtype: int64
# Ratings DataFrame after removing implicit ratings:
#    User-ID        ISBN  Book-Rating
# 1   276726   155061224            5
# 3   276729  052165615X            3
# 4   276729   521795028            6
# 6   276736  3257224281            8
# 7   276737   600570967            6

# %% [markdown]
# ## Feature engineering
#
#
# Now , lets explore potential features in `books_df` and `users_df` that can be generated from the datasets. Something like, user demographics, book genres, publication years, author popularity, etc. Decide on the features to be used for the recommendation system based on the chosen model approach.

# %%
print("Exploring features in books_df:")
print(books_df[['Year-Of-Publication', 'Publisher', 'Book-Author']].nunique()) #To Understand the diversity of the data (e.g., how many authors or publishers).

print("\nExploring features in users_df:")
print(users_df[['Location', 'Age']].nunique()) #Gives insights to understand how many different locations and ages are present in the user data.

# Example of extracting features from Location
users_df['Country'] = users_df['Location'].apply(lambda x: x.split(',')[-1].strip()) #extract only country from the location.
print("\nUnique countries in users_df:")
print(users_df['Country'].nunique())

# Example of categorizing Age
users_df['Age_Group'] = pd.cut(users_df['Age'], bins=[0, 18, 30, 50, 70, 100], labels=['0-17', '18-29', '30-49', '50-69', '70+']) #age brackets help understand the model generalize the age(usually such age groups have same interest,etc)
print("\nAge group distribution:")
print(users_df['Age_Group'].value_counts())
# Out:
# Exploring features in books_df:
# Year-Of-Publication       202
# Publisher               16806
# Book-Author            102022
# dtype: int64
#
# Exploring features in users_df:
# Location    57339
# Age            86
# dtype: int64
#
# Unique countries in users_df:
# 710
#
# Age group distribution:
# Age_Group
# 30-49    178225
# 18-29     60267
# 50-69     23702
# 0-17      15131
# 70+        1533
# Name: count, dtype: int64

# %% [markdown]
# ## Missing Values

# %%
print("Missing values in books_df:")
print(books_df.isnull().sum())
# Out:
# Missing values in books_df:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %% [markdown]
# ## Remove Books with Missing Critical Info

# %%
books_df.dropna(subset=['ISBN', 'Book-Title', 'Book-Author'], inplace=True)

# %%
print("Missing values after dropping rows with missing ISBN, Title, or Author:")
print(books_df[['ISBN', 'Book-Title', 'Book-Author']].isnull().sum())
# Out:
# Missing values after dropping rows with missing ISBN, Title, or Author:
# ISBN           0
# Book-Title     0
# Book-Author    0
# dtype: int64

# %%
print("Missing values in books_df after dropping rows:")
print(books_df.isnull().sum())
# Out:
# Missing values in books_df after dropping rows:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
#Dropping rows with missing Publisher values

books_df.dropna(subset=['Publisher'], inplace=True)

# %%
# Filling with a placeholder image URL
placeholder_url = 'https://via.placeholder.com/150'
books_df['Image-URL-L'] = books_df['Image-URL-L'].fillna(placeholder_url)

# %%
print("Final missing value check:")
print(books_df.isnull().sum())
# Out:
# Final missing value check:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
#  Merge ratings with books on ISBN
ratings_books_df = ratings_df.merge(books_df, on='ISBN')

#  Merge with users on User-ID
final_df = ratings_books_df.merge(users_df, on='User-ID')

# %%
print("Final merged dataset shape:", final_df.shape)
print("Missing values after merging:")
print(final_df.isnull().sum())
# Out:
# Final merged dataset shape: (351853, 14)
# Missing values after merging:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# Location               0
# Age                    0
# Country                0
# Age_Group              0
# dtype: int64

# %%
#Most Rated Books

import matplotlib.pyplot as plt

top_books = final_df['Book-Title'].value_counts().head(10)
plt.figure(figsize=(10,5))
top_books.plot(kind='barh', color='skyblue')
plt.title('Top 10 Most Rated Books')
plt.xlabel('Number of Ratings')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### Insights:
#
# - "The Lovely Bones: A Novel" is the most rated book, followed by "Wild Animus" and "The Da Vinci Code".
#
# - These books are either very popular, frequently promoted, or included in many users' libraries.
#
# - This confirms a popularity bias, which is common in recommendation datasets.

# %%
#Most Active Users
top_users = final_df['User-ID'].value_counts().head(10)
plt.figure(figsize=(10,5))
top_users.plot(kind='bar', color='orange')
plt.title('Top 10 Most Active Users')
plt.ylabel('Number of Ratings Given')
plt.xlabel('User ID')
plt.show()

# %% [markdown]
# ### Insights:
#
# - One user (11676) has rated nearly 7,000 books, which is far above others this is likely an outlier.
#
# - Other users also show high activity, suggesting a long tail of frequent raters.

# %%
#Ratings Distribution
import seaborn as sns

plt.figure(figsize=(8,4))
sns.countplot(x='Book-Rating', data=final_df, palette='viridis')
plt.title('Distribution of Ratings')
plt.xlabel('Rating Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_27564\2620036736.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Book-Rating', data=final_df, palette='viridis')

# %% [markdown]
# ###Insights:
#
# - Most users give high ratings: 8, 9, and 10 dominate.
#
# - Very few ratings are 1–4.
#
# - This indicates a positive skew, meaning users mostly give favorable reviews.

# %%
#Users by Age Group
plt.figure(figsize=(8,4))
sns.countplot(x='Age_Group', data=final_df, order=['0-17', '18-29', '30-49', '50-69', '70+'], palette='Set2')
plt.title('User Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('User Count')
plt.show()
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_27564\671964653.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age_Group', data=final_df, order=['0-17', '18-29', '30-49', '50-69', '70+'], palette='Set2')

# %% [markdown]
# ### Insights:
#
# - Most users fall in the 30–49 age bracket, followed by 18–29.
#
# - Very few users in the 70+ and 0–17 groups.

# %%
#Country-wise User Count
top_countries = final_df['Country'].value_counts().head(10)
plt.figure(figsize=(10,5))
top_countries.plot(kind='bar', color='lightgreen')
plt.title('Top 10 Countries by User Count')
plt.ylabel('Number of Users')
plt.xlabel('Country')
plt.show()

# %% [markdown]
# ### Insights:
#
# - USA dominates with a huge margin.
#
# - Other countries (Canada, UK, Germany, etc.) have much fewer users.
#
# - There’s a long tail of less-represented countries.

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## Popularity Based Filtering

# %%
books = pd.read_csv('Books.csv',encoding='ISO-8859-1')
users = pd.read_csv('Users.csv',encoding='ISO-8859-1')
ratings = pd.read_csv('Ratings.csv',encoding='ISO-8859-1')
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_27564\592877685.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv',encoding='ISO-8859-1')

# %%
ratings
# Out:
#          User-ID        ISBN  Book-Rating
# 0         276725  034545104X            0
# 1         276726   155061224            5
# 2         276727   446520802            0
# 3         276729  052165615X            3
# 4         276729   521795028            6
# ...          ...         ...          ...
# 1048570   250764   451410777            0
# 1048571   250764   452264464            8
# 1048572   250764  048623715X            0
# 1048573   250764   486256588            0
# 1048574   250764   515069434            0
#
# [1048575 rows x 3 columns]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355   440400988                         There's a Bat in Bunk Five
# 271356   525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358   192126040                        Republic (World's Classics)
# 271359   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
ratings_with_name
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1        276726   155061224            5
# 2        276727   446520802            0
# 3        276729  052165615X            3
# 4        276729   521795028            6
# ...         ...         ...          ...
# 941107   250764   451410777            0
# 941108   250764   452264464            8
# 941109   250764  048623715X            0
# 941110   250764   486256588            0
# 941111   250764   515069434            0
#
#                                                Book-Title      Book-Author  \
# 0                                    Flesh Tones: A Novel       M. J. Rose
# 1                                        Rites of Passage       Judith Rae
# 2                                            The Notebook  Nicholas Sparks
# 3                                          Help!: Level 1    Philip Prowse
# 4       The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
# ...                                                   ...              ...
# 941107                            Sleep Tight (Onyx Book)     Anne Frasier
# 941108               Beloved (Plume Contemporary Fiction)    Toni Morrison
# 941109  Glamorous Movie Stars of the Thirties: Paper D...      Tom Tierney
# 941110  Schiaparelli Fashion Review: Paper Dolls in Fu...      Tom Tierney
# 941111           Lady Laughing Eyes (To Have and to Hold)        Lee Damon
#
#        Year-Of-Publication                   Publisher  \
# 0                     2002            Ballantine Books
# 1                     2001                      Heinle
# 2                     1996                Warner Books
# 3                     1999  Cambridge University Press
# 4                     2001  Cambridge University Press
# ...                    ...                         ...
# 941107                2003                  Onyx Books
# 941108                1994                       Plume
# 941109                1982          Dover Publications
# 941110                1988          Dover Publications
# 941111                1984                  Jove Books
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/0155061224.0...
# 2       http://images.amazon.com/images/P/0446520802.0...
# 3       http://images.amazon.com/images/P/052165615X.0...
# 4       http://images.amazon.com/images/P/0521795028.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/0155061224.0...
# 2       http://images.amazon.com/images/P/0446520802.0...
# 3       http://images.amazon.com/images/P/052165615X.0...
# 4       http://images.amazon.com/images/P/0521795028.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/0155061224.0...
# 2       http://images.amazon.com/images/P/0446520802.0...
# 3       http://images.amazon.com/images/P/052165615X.0...
# 4       http://images.amazon.com/images/P/0521795028.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
# [941112 rows x 10 columns]

# %%
ratings_with_name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941112 entries, 0 to 941111
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   User-ID              941112 non-null  int64
#  1   ISBN                 941112 non-null  object
#  2   Book-Rating          941112 non-null  int64
#  3   Book-Title           941112 non-null  object
#  4   Book-Author          941110 non-null  object
#  5   Year-Of-Publication  941112 non-null  object
#  6   Publisher            941110 non-null  object
#  7   Image-URL-S          941112 non-null  object
#  8   Image-URL-M          941112 non-null  object
#  9   Image-URL-L          941108 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 71.8+ MB

# %%
ratings_with_name.isna().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            4
# dtype: int64

# %% [markdown]
# As there are very few null values, I will drop them.

# %%
ratings_with_name.dropna(inplace=True)

# %%
ratings_with_name.isna().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
ratings_with_name['ISBN'].value_counts()
# Out:
# ISBN
# 971880107    2264
# 316666343    1164
# 385504209     813
# 312195516     668
# 60928336      662
#              ...
# 898654572       1
# 887069789       1
# 880386495       1
# 880384522       1
# 515069434       1
# Name: count, Length: 257807, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_rating_df.rename(columns = {"Book-Rating":'Num-Ratings'},inplace=True)

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# 4        Clifford Visita El Hospital (Clifford El Gran...     0.000000
# ...                                                   ...          ...
# 230209                                       voyage fatal     0.000000
# 230210                                       waking blood     6.000000
# 230211                             wet sand, raven tracks     4.000000
# 230212  whataboutrick.com: a poetic tribute to Richard...     2.500000
# 230213                   why I'm like this : True Stories     4.272727
#
# [230214 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')

# %%
popular_df.rename(columns ={'Book-Rating':"Avg-Ratings"},inplace=True)

# %%
popular_df1 = popular_df[popular_df['Num-Ratings']>250].sort_values('Avg-Ratings',ascending=False).head(25)

# %%
popular_df1
# Out:
#                                                Book-Title  Num-Ratings  \
# 76892        Harry Potter and the Goblet of Fire (Book 4)          346
# 76904   Harry Potter and the Prisoner of Azkaban (Book 3)          380
# 76896   Harry Potter and the Order of the Phoenix (Boo...          316
# 76884    Harry Potter and the Chamber of Secrets (Book 2)          501
# 182960  The Hobbit : The Enchanting Prelude to The Lor...          261
# 76915   Harry Potter and the Sorcerer's Stone (Harry P...          519
# 178925  The Fellowship of the Ring (The Lord of the Ri...          340
# 209869                              To Kill a Mockingbird          463
# 175304                                  The Da Vinci Code          828
# 172433                             The Catcher in the Rye          401
# 197238                            The Secret Life of Bees          704
# 179411                 The Five People You Meet in Heaven          392
# 187482                          The Lovely Bones: A Novel         1164
# 727                                                  1984          259
# 182938               The Hitchhiker's Guide to the Galaxy          252
# 161113  Stupid White Men ...and Other Sorry Excuses fo...          264
# 195209                The Red Tent (Bestselling Backlist)          668
# 213134  Tuesdays with Morrie: An Old Man, a Young Man,...          437
# 123550   Nickel and Dimed: On (Not) Getting By in America          303
# 61128                                      Fahrenheit 451          372
# 71478                           Girl with a Pearl Earring          486
# 62139   Fast Food Nation: The Dark Side of the All-Ame...          285
# 72998                                         Good in Bed          456
# 129997                                          Outlander          262
# 222924  Where the Heart Is (Oprah's Book Club (Paperba...          527
#
#         Avg-Ratings
# 76892      5.945087
# 76904      5.884211
# 76896      5.544304
# 76884      5.177645
# 182960     4.969349
# 76915      4.938343
# 178925     4.885294
# 209869     4.684665
# 175304     4.679952
# 172433     4.615960
# 197238     4.558239
# 179411     4.543367
# 187482     4.457045
# 727        4.393822
# 182938     4.361111
# 161113     4.337121
# 195209     4.326347
# 213134     4.274600
# 123550     4.244224
# 61128      4.239247
# 71478      4.197531
# 62139      4.133333
# 72998      4.127193
# 129997     4.087786
# 222924     4.070209

# %% [markdown]
# num-ratings>250 gives more reliable recommendations, because when I used num-ratings > 500 the avg ratings became less than 3 meaning more people didnt like the book that much. So to get more reliable recommendation I used num-ratings >250

# %%
final_popular_df=popular_df1.merge(books,on = 'Book-Title')

# %%
final_popular_df
# Out:
#                                             Book-Title  Num-Ratings  \
# 0         Harry Potter and the Goblet of Fire (Book 4)          346
# 1         Harry Potter and the Goblet of Fire (Book 4)          346
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)          380
# 3    Harry Potter and the Prisoner of Azkaban (Book 3)          380
# 4    Harry Potter and the Prisoner of Azkaban (Book 3)          380
# ..                                                 ...          ...
# 100                                          Outlander          262
# 101                                          Outlander          262
# 102                                          Outlander          262
# 103                                          Outlander          262
# 104  Where the Heart Is (Oprah's Book Club (Paperba...          527
#
#      Avg-Ratings       ISBN     Book-Author Year-Of-Publication  \
# 0       5.945087  439139597   J. K. Rowling                2000
# 1       5.945087  439139600   J. K. Rowling                2002
# 2       5.884211  439136350   J. K. Rowling                1999
# 3       5.884211  439136369   J. K. Rowling                2001
# 4       5.884211  786222743   J. K. Rowling                2000
# ..           ...        ...             ...                 ...
# 100     4.087786  440212561  DIANA GABALDON                1992
# 101     4.087786  385302304  DIANA GABALDON                1991
# 102     4.087786  553473298  DIANA GABALDON                1994
# 103     4.087786  930044177       Jane Rule                1981
# 104     4.070209  446672211    Billie Letts                1998
#
#                  Publisher                                        Image-URL-S  \
# 0               Scholastic  http://images.amazon.com/images/P/0439139597.0...
# 1    Scholastic Paperbacks  http://images.amazon.com/images/P/0439139600.0...
# 2               Scholastic  http://images.amazon.com/images/P/0439136350.0...
# 3               Scholastic  http://images.amazon.com/images/P/0439136369.0...
# 4          Thorndike Press  http://images.amazon.com/images/P/0786222743.0...
# ..                     ...                                                ...
# 100                   Dell  http://images.amazon.com/images/P/0440212561.0...
# 101        Delacorte Press  http://images.amazon.com/images/P/0385302304.0...
# 102     Random House Audio  http://images.amazon.com/images/P/0553473298.0...
# 103            Naiad Press  http://images.amazon.com/images/P/0930044177.0...
# 104           Warner Books  http://images.amazon.com/images/P/0446672211.0...
#
#                                            Image-URL-M  \
# 0    http://images.amazon.com/images/P/0439139597.0...
# 1    http://images.amazon.com/images/P/0439139600.0...
# 2    http://images.amazon.com/images/P/0439136350.0...
# 3    http://images.amazon.com/images/P/0439136369.0...
# 4    http://images.amazon.com/images/P/0786222743.0...
# ..                                                 ...
# 100  http://images.amazon.com/images/P/0440212561.0...
# 101  http://images.amazon.com/images/P/0385302304.0...
# 102  http://images.amazon.com/images/P/0553473298.0...
# 103  http://images.amazon.com/images/P/0930044177.0...
# 104  http://images.amazon.com/images/P/0446672211.0...
#
#                                            Image-URL-L
# 0    http://images.amazon.com/images/P/0439139597.0...
# 1    http://images.amazon.com/images/P/0439139600.0...
# 2    http://images.amazon.com/images/P/0439136350.0...
# 3    http://images.amazon.com/images/P/0439136369.0...
# 4    http://images.amazon.com/images/P/0786222743.0...
# ..                                                 ...
# 100  http://images.amazon.com/images/P/0440212561.0...
# 101  http://images.amazon.com/images/P/0385302304.0...
# 102  http://images.amazon.com/images/P/0553473298.0...
# 103  http://images.amazon.com/images/P/0930044177.0...
# 104  http://images.amazon.com/images/P/0446672211.0...
#
# [105 rows x 10 columns]

# %% [markdown]
# We can see that there are multiple books with same titles. we need to drop those duplicates and keep the original values.

# %%
final_popular_df.drop_duplicates('Book-Title',inplace=True)

# %%
final_popular_df
# Out:
#                                             Book-Title  Num-Ratings  \
# 0         Harry Potter and the Goblet of Fire (Book 4)          346
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)          380
# 5    Harry Potter and the Order of the Phoenix (Boo...          316
# 9     Harry Potter and the Chamber of Secrets (Book 2)          501
# 12   The Hobbit : The Enchanting Prelude to The Lor...          261
# 13   Harry Potter and the Sorcerer's Stone (Harry P...          519
# 15   The Fellowship of the Ring (The Lord of the Ri...          340
# 24                               To Kill a Mockingbird          463
# 32                                   The Da Vinci Code          828
# 38                              The Catcher in the Rye          401
# 45                             The Secret Life of Bees          704
# 51                  The Five People You Meet in Heaven          392
# 53                           The Lovely Bones: A Novel         1164
# 54                                                1984          259
# 65                The Hitchhiker's Guide to the Galaxy          252
# 74   Stupid White Men ...and Other Sorry Excuses fo...          264
# 75                 The Red Tent (Bestselling Backlist)          668
# 76   Tuesdays with Morrie: An Old Man, a Young Man,...          437
# 79    Nickel and Dimed: On (Not) Getting By in America          303
# 81                                      Fahrenheit 451          372
# 94                           Girl with a Pearl Earring          486
# 95   Fast Food Nation: The Dark Side of the All-Ame...          285
# 96                                         Good in Bed          456
# 98                                           Outlander          262
# 104  Where the Heart Is (Oprah's Book Club (Paperba...          527
#
#      Avg-Ratings        ISBN         Book-Author Year-Of-Publication  \
# 0       5.945087   439139597       J. K. Rowling                2000
# 2       5.884211   439136350       J. K. Rowling                1999
# 5       5.544304  043935806X       J. K. Rowling                2003
# 9       5.177645   439064872       J. K. Rowling                2000
# 12      4.969349   345339681      J.R.R. TOLKIEN                1986
# 13      4.938343  059035342X       J. K. Rowling                1999
# 15      4.885294   345339703      J.R.R. TOLKIEN                1986
# 24      4.684665   446310786          Harper Lee                1988
# 32      4.679952   385504209           Dan Brown                2003
# 38      4.615960   316769487       J.D. Salinger                1991
# 45      4.558239   142001740       Sue Monk Kidd                2003
# 51      4.543367   786868716         Mitch Albom                2003
# 53      4.457045   316666343        Alice Sebold                2002
# 54      4.393822   451524934       George Orwell                1990
# 65      4.361111   671461494       Douglas Adams                1982
# 74      4.337121    60392452       Michael Moore                2002
# 75      4.326347   312195516       Anita Diamant                1998
# 76      4.274600   385484518         MITCH ALBOM                1997
# 79      4.244224   805063897  Barbara Ehrenreich                2002
# 81      4.239247  3257208626        Ray Bradbury                1994
# 94      4.197531   452282152     Tracy Chevalier                2001
# 95      4.133333    60938455      Eric Schlosser                2002
# 96      4.127193   743418174     Jennifer Weiner                2002
# 98      4.087786   440222915      DIANA GABALDON                1996
# 104     4.070209   446672211        Billie Letts                1998
#
#                       Publisher  \
# 0                    Scholastic
# 2                    Scholastic
# 5                    Scholastic
# 9                    Scholastic
# 12                      Del Rey
# 13       Arthur A. Levine Books
# 15                      Del Rey
# 24   Little Brown &amp; Company
# 32                    Doubleday
# 38                Little, Brown
# 45                Penguin Books
# 51                     Hyperion
# 53                Little, Brown
# 54                  Signet Book
# 65                       Pocket
# 74                  Regan Books
# 75                  Picador USA
# 76                    Doubleday
# 79                    Owl Books
# 81              Distribooks Inc
# 94                  Plume Books
# 95                    Perennial
# 96      Washington Square Press
# 98                         Dell
# 104                Warner Books
#
#                                            Image-URL-S  \
# 0    http://images.amazon.com/images/P/0439139597.0...
# 2    http://images.amazon.com/images/P/0439136350.0...
# 5    http://images.amazon.com/images/P/043935806X.0...
# 9    http://images.amazon.com/images/P/0439064872.0...
# 12   http://images.amazon.com/images/P/0345339681.0...
# 13   http://images.amazon.com/images/P/059035342X.0...
# 15   http://images.amazon.com/images/P/0345339703.0...
# 24   http://images.amazon.com/images/P/0446310786.0...
# 32   http://images.amazon.com/images/P/0385504209.0...
# 38   http://images.amazon.com/images/P/0316769487.0...
# 45   http://images.amazon.com/images/P/0142001740.0...
# 51   http://images.amazon.com/images/P/0786868716.0...
# 53   http://images.amazon.com/images/P/0316666343.0...
# 54   http://images.amazon.com/images/P/0451524934.0...
# 65   http://images.amazon.com/images/P/0671461494.0...
# 74   http://images.amazon.com/images/P/0060392452.0...
# 75   http://images.amazon.com/images/P/0312195516.0...
# 76   http://images.amazon.com/images/P/0385484518.0...
# 79   http://images.amazon.com/images/P/0805063897.0...
# 81   http://images.amazon.com/images/P/3257208626.0...
# 94   http://images.amazon.com/images/P/0452282152.0...
# 95   http://images.amazon.com/images/P/0060938455.0...
# 96   http://images.amazon.com/images/P/0743418174.0...
# 98   http://images.amazon.com/images/P/0440222915.0...
# 104  http://images.amazon.com/images/P/0446672211.0...
#
#                                            Image-URL-M  \
# 0    http://images.amazon.com/images/P/0439139597.0...
# 2    http://images.amazon.com/images/P/0439136350.0...
# 5    http://images.amazon.com/images/P/043935806X.0...
# 9    http://images.amazon.com/images/P/0439064872.0...
# 12   http://images.amazon.com/images/P/0345339681.0...
# 13   http://images.amazon.com/images/P/059035342X.0...
# 15   http://images.amazon.com/images/P/0345339703.0...
# 24   http://images.amazon.com/images/P/0446310786.0...
# 32   http://images.amazon.com/images/P/0385504209.0...
# 38   http://images.amazon.com/images/P/0316769487.0...
# 45   http://images.amazon.com/images/P/0142001740.0...
# 51   http://images.amazon.com/images/P/0786868716.0...
# 53   http://images.amazon.com/images/P/0316666343.0...
# 54   http://images.amazon.com/images/P/0451524934.0...
# 65   http://images.amazon.com/images/P/0671461494.0...
# 74   http://images.amazon.com/images/P/0060392452.0...
# 75   http://images.amazon.com/images/P/0312195516.0...
# 76   http://images.amazon.com/images/P/0385484518.0...
# 79   http://images.amazon.com/images/P/0805063897.0...
# 81   http://images.amazon.com/images/P/3257208626.0...
# 94   http://images.amazon.com/images/P/0452282152.0...
# 95   http://images.amazon.com/images/P/0060938455.0...
# 96   http://images.amazon.com/images/P/0743418174.0...
# 98   http://images.amazon.com/images/P/0440222915.0...
# 104  http://images.amazon.com/images/P/0446672211.0...
#
#                                            Image-URL-L
# 0    http://images.amazon.com/images/P/0439139597.0...
# 2    http://images.amazon.com/images/P/0439136350.0...
# 5    http://images.amazon.com/images/P/043935806X.0...
# 9    http://images.amazon.com/images/P/0439064872.0...
# 12   http://images.amazon.com/images/P/0345339681.0...
# 13   http://images.amazon.com/images/P/059035342X.0...
# 15   http://images.amazon.com/images/P/0345339703.0...
# 24   http://images.amazon.com/images/P/0446310786.0...
# 32   http://images.amazon.com/images/P/0385504209.0...
# 38   http://images.amazon.com/images/P/0316769487.0...
# 45   http://images.amazon.com/images/P/0142001740.0...
# 51   http://images.amazon.com/images/P/0786868716.0...
# 53   http://images.amazon.com/images/P/0316666343.0...
# 54   http://images.amazon.com/images/P/0451524934.0...
# 65   http://images.amazon.com/images/P/0671461494.0...
# 74   http://images.amazon.com/images/P/0060392452.0...
# 75   http://images.amazon.com/images/P/0312195516.0...
# 76   http://images.amazon.com/images/P/0385484518.0...
# 79   http://images.amazon.com/images/P/0805063897.0...
# 81   http://images.amazon.com/images/P/3257208626.0...
# 94   http://images.amazon.com/images/P/0452282152.0...
# 95   http://images.amazon.com/images/P/0060938455.0...
# 96   http://images.amazon.com/images/P/0743418174.0...
# 98   http://images.amazon.com/images/P/0440222915.0...
# 104  http://images.amazon.com/images/P/0446672211.0...

# %%
final_popular_df.columns
# Out:
# Index(['Book-Title', 'Num-Ratings', 'Avg-Ratings', 'ISBN', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L'],
#       dtype='object')

# %%
final_popular_df.drop(columns = ['Publisher','Image-URL-S','Image-URL-L'],inplace=True)

# %%
final_popular_df.reset_index(inplace=True)

# %%
final_popular_df.drop(columns='index',inplace=True)

# %% [markdown]
# ## These are the Top 25 books which are most Popular.

# %%
final_popular_df
# Out:
#                                            Book-Title  Num-Ratings  \
# 0        Harry Potter and the Goblet of Fire (Book 4)          346
# 1   Harry Potter and the Prisoner of Azkaban (Book 3)          380
# 2   Harry Potter and the Order of the Phoenix (Boo...          316
# 3    Harry Potter and the Chamber of Secrets (Book 2)          501
# 4   The Hobbit : The Enchanting Prelude to The Lor...          261
# 5   Harry Potter and the Sorcerer's Stone (Harry P...          519
# 6   The Fellowship of the Ring (The Lord of the Ri...          340
# 7                               To Kill a Mockingbird          463
# 8                                   The Da Vinci Code          828
# 9                              The Catcher in the Rye          401
# 10                            The Secret Life of Bees          704
# 11                 The Five People You Meet in Heaven          392
# 12                          The Lovely Bones: A Novel         1164
# 13                                               1984          259
# 14               The Hitchhiker's Guide to the Galaxy          252
# 15  Stupid White Men ...and Other Sorry Excuses fo...          264
# 16                The Red Tent (Bestselling Backlist)          668
# 17  Tuesdays with Morrie: An Old Man, a Young Man,...          437
# 18   Nickel and Dimed: On (Not) Getting By in America          303
# 19                                     Fahrenheit 451          372
# 20                          Girl with a Pearl Earring          486
# 21  Fast Food Nation: The Dark Side of the All-Ame...          285
# 22                                        Good in Bed          456
# 23                                          Outlander          262
# 24  Where the Heart Is (Oprah's Book Club (Paperba...          527
#
#     Avg-Ratings        ISBN         Book-Author Year-Of-Publication  \
# 0      5.945087   439139597       J. K. Rowling                2000
# 1      5.884211   439136350       J. K. Rowling                1999
# 2      5.544304  043935806X       J. K. Rowling                2003
# 3      5.177645   439064872       J. K. Rowling                2000
# 4      4.969349   345339681      J.R.R. TOLKIEN                1986
# 5      4.938343  059035342X       J. K. Rowling                1999
# 6      4.885294   345339703      J.R.R. TOLKIEN                1986
# 7      4.684665   446310786          Harper Lee                1988
# 8      4.679952   385504209           Dan Brown                2003
# 9      4.615960   316769487       J.D. Salinger                1991
# 10     4.558239   142001740       Sue Monk Kidd                2003
# 11     4.543367   786868716         Mitch Albom                2003
# 12     4.457045   316666343        Alice Sebold                2002
# 13     4.393822   451524934       George Orwell                1990
# 14     4.361111   671461494       Douglas Adams                1982
# 15     4.337121    60392452       Michael Moore                2002
# 16     4.326347   312195516       Anita Diamant                1998
# 17     4.274600   385484518         MITCH ALBOM                1997
# 18     4.244224   805063897  Barbara Ehrenreich                2002
# 19     4.239247  3257208626        Ray Bradbury                1994
# 20     4.197531   452282152     Tracy Chevalier                2001
# 21     4.133333    60938455      Eric Schlosser                2002
# 22     4.127193   743418174     Jennifer Weiner                2002
# 23     4.087786   440222915      DIANA GABALDON                1996
# 24     4.070209   446672211        Billie Letts                1998
#
#                                           Image-URL-M
# 0   http://images.amazon.com/images/P/0439139597.0...
# 1   http://images.amazon.com/images/P/0439136350.0...
# 2   http://images.amazon.com/images/P/043935806X.0...
# 3   http://images.amazon.com/images/P/0439064872.0...
# 4   http://images.amazon.com/images/P/0345339681.0...
# 5   http://images.amazon.com/images/P/059035342X.0...
# 6   http://images.amazon.com/images/P/0345339703.0...
# 7   http://images.amazon.com/images/P/0446310786.0...
# 8   http://images.amazon.com/images/P/0385504209.0...
# 9   http://images.amazon.com/images/P/0316769487.0...
# 10  http://images.amazon.com/images/P/0142001740.0...
# 11  http://images.amazon.com/images/P/0786868716.0...
# 12  http://images.amazon.com/images/P/0316666343.0...
# 13  http://images.amazon.com/images/P/0451524934.0...
# 14  http://images.amazon.com/images/P/0671461494.0...
# 15  http://images.amazon.com/images/P/0060392452.0...
# 16  http://images.amazon.com/images/P/0312195516.0...
# 17  http://images.amazon.com/images/P/0385484518.0...
# 18  http://images.amazon.com/images/P/0805063897.0...
# 19  http://images.amazon.com/images/P/3257208626.0...
# 20  http://images.amazon.com/images/P/0452282152.0...
# 21  http://images.amazon.com/images/P/0060938455.0...
# 22  http://images.amazon.com/images/P/0743418174.0...
# 23  http://images.amazon.com/images/P/0440222915.0...
# 24  http://images.amazon.com/images/P/0446672211.0...

# %%
final_popular_df['Image-URL-M']
# Out:
# 0     http://images.amazon.com/images/P/0439139597.0...
# 1     http://images.amazon.com/images/P/0439136350.0...
# 2     http://images.amazon.com/images/P/043935806X.0...
# 3     http://images.amazon.com/images/P/0439064872.0...
# 4     http://images.amazon.com/images/P/0345339681.0...
# 5     http://images.amazon.com/images/P/059035342X.0...
# 6     http://images.amazon.com/images/P/0345339703.0...
# 7     http://images.amazon.com/images/P/0446310786.0...
# 8     http://images.amazon.com/images/P/0385504209.0...
# 9     http://images.amazon.com/images/P/0316769487.0...
# 10    http://images.amazon.com/images/P/0142001740.0...
# 11    http://images.amazon.com/images/P/0786868716.0...
# 12    http://images.amazon.com/images/P/0316666343.0...
# 13    http://images.amazon.com/images/P/0451524934.0...
# 14    http://images.amazon.com/images/P/0671461494.0...
# 15    http://images.amazon.com/images/P/0060392452.0...
# 16    http://images.amazon.com/images/P/0312195516.0...
# 17    http://images.amazon.com/images/P/0385484518.0...
# 18    http://images.amazon.com/images/P/0805063897.0...
# 19    http://images.amazon.com/images/P/3257208626.0...
# 20    http://images.amazon.com/images/P/0452282152.0...
# 21    http://images.amazon.com/images/P/0060938455.0...
# 22    http://images.amazon.com/images/P/0743418174.0...
# 23    http://images.amazon.com/images/P/0440222915.0...
# 24    http://images.amazon.com/images/P/0446672211.0...
# Name: Image-URL-M, dtype: object

# %%
import joblib
joblib.dump(final_popular_df,"Most_Popular_Books.pkl")
# Out:
# ['Most_Popular_Books.pkl']

# %%
len(final_popular_df)
# Out:
# 25

# %% [markdown]
# ## User-based collaborative Filtering

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355   440400988                         There's a Bat in Bunk Five
# 271356   525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358   192126040                        Republic (World's Classics)
# 271359   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings
# Out:
#          User-ID        ISBN  Book-Rating
# 0         276725  034545104X            0
# 1         276726   155061224            5
# 2         276727   446520802            0
# 3         276729  052165615X            3
# 4         276729   521795028            6
# ...          ...         ...          ...
# 1048570   250764   451410777            0
# 1048571   250764   452264464            8
# 1048572   250764  048623715X            0
# 1048573   250764   486256588            0
# 1048574   250764   515069434            0
#
# [1048575 rows x 3 columns]

# %% [markdown]
# We need to have a data frame which contains user in the columns and books in the rows and ratings in their values for collaborative filtering like shown below:

# %% [raw]
#         user1   user2   user3   user4 ... userN
# book1     5       6       4        8        6
# book2     6       8       3        6        7
# ....     ...     ...     ...      ...      ...
# bookN     3       1       7        5        9

# %% [markdown]
# Here the values in the above table are ratings given by the user for the book.

# %%
ratings_with_name
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1        276726   155061224            5
# 2        276727   446520802            0
# 3        276729  052165615X            3
# 4        276729   521795028            6
# ...         ...         ...          ...
# 941107   250764   451410777            0
# 941108   250764   452264464            8
# 941109   250764  048623715X            0
# 941110   250764   486256588            0
# 941111   250764   515069434            0
#
#                                                Book-Title      Book-Author  \
# 0                                    Flesh Tones: A Novel       M. J. Rose
# 1                                        Rites of Passage       Judith Rae
# 2                                            The Notebook  Nicholas Sparks
# 3                                          Help!: Level 1    Philip Prowse
# 4       The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
# ...                                                   ...              ...
# 941107                            Sleep Tight (Onyx Book)     Anne Frasier
# 941108               Beloved (Plume Contemporary Fiction)    Toni Morrison
# 941109  Glamorous Movie Stars of the Thirties: Paper D...      Tom Tierney
# 941110  Schiaparelli Fashion Review: Paper Dolls in Fu...      Tom Tierney
# 941111           Lady Laughing Eyes (To Have and to Hold)        Lee Damon
#
#        Year-Of-Publication                   Publisher  \
# 0                     2002            Ballantine Books
# 1                     2001                      Heinle
# 2                     1996                Warner Books
# 3                     1999  Cambridge University Press
# 4                     2001  Cambridge University Press
# ...                    ...                         ...
# 941107                2003                  Onyx Books
# 941108                1994                       Plume
# 941109                1982          Dover Publications
# 941110                1988          Dover Publications
# 941111                1984                  Jove Books
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/0155061224.0...
# 2       http://images.amazon.com/images/P/0446520802.0...
# 3       http://images.amazon.com/images/P/052165615X.0...
# 4       http://images.amazon.com/images/P/0521795028.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/0155061224.0...
# 2       http://images.amazon.com/images/P/0446520802.0...
# 3       http://images.amazon.com/images/P/052165615X.0...
# 4       http://images.amazon.com/images/P/0521795028.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/0155061224.0...
# 2       http://images.amazon.com/images/P/0446520802.0...
# 3       http://images.amazon.com/images/P/052165615X.0...
# 4       http://images.amazon.com/images/P/0521795028.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
# [941104 rows x 10 columns]

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
knowledgable_users = x[x].index

# %%
knowledgable_users
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        249111, 249628, 249862, 249894, 250184, 250405, 250764, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=737)

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(knowledgable_users)]

# %%
filtered_rating
# Out:
#         User-ID        ISBN  Book-Rating  \
# 1153     277427  002542730X           10
# 1154     277427    26217457            0
# 1155     277427  003008685X            8
# 1156     277427    30615321            0
# 1157     277427    60002050            0
# ...         ...         ...          ...
# 941107   250764   451410777            0
# 941108   250764   452264464            8
# 941109   250764  048623715X            0
# 941110   250764   486256588            0
# 941111   250764   515069434            0
#
#                                                Book-Title  \
# 1153    Politically Correct Bedtime Stories: Modern Ta...
# 1154                   Vegetarian Times Complete Cookbook
# 1155                                             Pioneers
# 1156     Ask for May, Settle for June (A Doonesbury book)
# 1157                    On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# 941107                            Sleep Tight (Onyx Book)
# 941108               Beloved (Plume Contemporary Fiction)
# 941109  Glamorous Movie Stars of the Thirties: Paper D...
# 941110  Schiaparelli Fashion Review: Paper Dolls in Fu...
# 941111           Lady Laughing Eyes (To Have and to Hold)
#
#                   Book-Author Year-Of-Publication                  Publisher  \
# 1153        James Finn Garner                1994  John Wiley &amp; Sons Inc
# 1154               Lucy  Moll                1995      John Wiley &amp; Sons
# 1155    James Fenimore Cooper                1974           Thomson Learning
# 1156            G. B. Trudeau                1982        Henry Holt &amp; Co
# 1157        Stephanie Laurens                2002                 Avon Books
# ...                       ...                 ...                        ...
# 941107           Anne Frasier                2003                 Onyx Books
# 941108          Toni Morrison                1994                      Plume
# 941109            Tom Tierney                1982         Dover Publications
# 941110            Tom Tierney                1988         Dover Publications
# 941111              Lee Damon                1984                 Jove Books
#
#                                               Image-URL-S  \
# 1153    http://images.amazon.com/images/P/002542730X.0...
# 1154    http://images.amazon.com/images/P/0026217457.0...
# 1155    http://images.amazon.com/images/P/003008685X.0...
# 1156    http://images.amazon.com/images/P/0030615321.0...
# 1157    http://images.amazon.com/images/P/0060002050.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
#                                               Image-URL-M  \
# 1153    http://images.amazon.com/images/P/002542730X.0...
# 1154    http://images.amazon.com/images/P/0026217457.0...
# 1155    http://images.amazon.com/images/P/003008685X.0...
# 1156    http://images.amazon.com/images/P/0030615321.0...
# 1157    http://images.amazon.com/images/P/0060002050.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
#                                               Image-URL-L
# 1153    http://images.amazon.com/images/P/002542730X.0...
# 1154    http://images.amazon.com/images/P/0026217457.0...
# 1155    http://images.amazon.com/images/P/003008685X.0...
# 1156    http://images.amazon.com/images/P/0030615321.0...
# 1157    http://images.amazon.com/images/P/0060002050.0...
# ...                                                   ...
# 941107  http://images.amazon.com/images/P/0451410777.0...
# 941108  http://images.amazon.com/images/P/0452264464.0...
# 941109  http://images.amazon.com/images/P/048623715X.0...
# 941110  http://images.amazon.com/images/P/0486256588.0...
# 941111  http://images.amazon.com/images/P/0515069434.0...
#
# [434816 rows x 10 columns]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
y[y]
# Out:
# Book-Title
# 1984                                                                 True
# 1st to Die: A Novel                                                  True
# 2nd Chance                                                           True
# 4 Blondes                                                            True
# A Bend in the Road                                                   True
#                                                                      ...
# Year of Wonders                                                      True
# You Belong To Me                                                     True
# Zen and the Art of Motorcycle Maintenance: An Inquiry into Values    True
# Zoya                                                                 True
# \O\" Is for Outlaw"                                                  True
# Name: Book-Rating, Length: 603, dtype: bool

# %%
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Moon', 'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wuthering Heights', 'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=603)

# %%
final_ratings_df = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings_df
# Out:
#         User-ID        ISBN  Book-Rating  \
# 1153     277427  002542730X           10
# 1166     277427    60930535            0
# 1168     277427    60934417            0
# 1171     277427    61009059            9
# 1177     277427  006440188X            0
# ...         ...         ...          ...
# 941065   250764   446364673            0
# 941086   250764   449907481            0
# 941093   250764   451180410            0
# 941095   250764   451191013            0
# 941097   250764   451192001            0
#
#                                                Book-Title  \
# 1153    Politically Correct Bedtime Stories: Modern Ta...
# 1166                        The Poisonwood Bible: A Novel
# 1168                                   Bel Canto: A Novel
# 1171    One for the Money (Stephanie Plum Novels (Pape...
# 1177                                    The Secret Garden
# ...                                                   ...
# 941065                                           The Gift
# 941086      A Thousand Acres (Ballantine Reader's Circle)
# 941093                                        Mortal Fear
# 941095                                     The Regulators
# 941097                     How Stella Got Her Groove Back
#
#                     Book-Author Year-Of-Publication  \
# 1153          James Finn Garner                1994
# 1166         Barbara Kingsolver                1999
# 1168               Ann Patchett                2002
# 1171            Janet Evanovich                1995
# 1177    Frances Hodgson Burnett                1998
# ...                         ...                 ...
# 941065             Kirk Douglas                1993
# 941086              JANE SMILEY                1992
# 941093                Greg Iles                1998
# 941095             Stephen King                2002
# 941097           Terry McMillan                1997
#
#                         Publisher  \
# 1153    John Wiley &amp; Sons Inc
# 1166                    Perennial
# 1168                    Perennial
# 1171                  HarperTorch
# 1177                 HarperTrophy
# ...                           ...
# 941065               Warner Books
# 941086           Ballantine Books
# 941093                Signet Book
# 941095                Signet Book
# 941097                Signet Book
#
#                                               Image-URL-S  \
# 1153    http://images.amazon.com/images/P/002542730X.0...
# 1166    http://images.amazon.com/images/P/0060930535.0...
# 1168    http://images.amazon.com/images/P/0060934417.0...
# 1171    http://images.amazon.com/images/P/0061009059.0...
# 1177    http://images.amazon.com/images/P/006440188X.0...
# ...                                                   ...
# 941065  http://images.amazon.com/images/P/0446364673.0...
# 941086  http://images.amazon.com/images/P/0449907481.0...
# 941093  http://images.amazon.com/images/P/0451180410.0...
# 941095  http://images.amazon.com/images/P/0451191013.0...
# 941097  http://images.amazon.com/images/P/0451192001.0...
#
#                                               Image-URL-M  \
# 1153    http://images.amazon.com/images/P/002542730X.0...
# 1166    http://images.amazon.com/images/P/0060930535.0...
# 1168    http://images.amazon.com/images/P/0060934417.0...
# 1171    http://images.amazon.com/images/P/0061009059.0...
# 1177    http://images.amazon.com/images/P/006440188X.0...
# ...                                                   ...
# 941065  http://images.amazon.com/images/P/0446364673.0...
# 941086  http://images.amazon.com/images/P/0449907481.0...
# 941093  http://images.amazon.com/images/P/0451180410.0...
# 941095  http://images.amazon.com/images/P/0451191013.0...
# 941097  http://images.amazon.com/images/P/0451192001.0...
#
#                                               Image-URL-L
# 1153    http://images.amazon.com/images/P/002542730X.0...
# 1166    http://images.amazon.com/images/P/0060930535.0...
# 1168    http://images.amazon.com/images/P/0060934417.0...
# 1171    http://images.amazon.com/images/P/0061009059.0...
# 1177    http://images.amazon.com/images/P/006440188X.0...
# ...                                                   ...
# 941065  http://images.amazon.com/images/P/0446364673.0...
# 941086  http://images.amazon.com/images/P/0449907481.0...
# 941093  http://images.amazon.com/images/P/0451180410.0...
# 941095  http://images.amazon.com/images/P/0451191013.0...
# 941097  http://images.amazon.com/images/P/0451192001.0...
#
# [48546 rows x 10 columns]

# %%
Pivot_df = final_ratings_df.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
Pivot_df
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             6543    ...  249111  \
# Book-Title                                                  ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    9.0  ...     NaN
# 2nd Chance                                             0.0  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             249628  249862  249894  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    0.0     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             250184  250405  250764  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       0.0     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     0.0
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [603 rows x 735 columns]

# %% [markdown]
# Filling all the NULL values with 0 to apply cosine similarity, which helps us find similar users

# %%
Pivot_df.fillna(0,inplace=True)

# %%
Pivot_df
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  249111  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             249628  249862  249894  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             250184  250405  250764  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [603 rows x 735 columns]

# %% [markdown]
# As we can see there are 603 books which are popular and 735 users who have rated more than 200 books meaning they are knowledeagble which means their ratings can be trusted.

# %% [markdown]
#  Now lets apply cosine distances for every user to find which users are similar which can be determined by smallest distance between each other.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
Similarity_scores = cosine_similarity(Pivot_df)

# %%
Similarity_scores[0] # this is similarity score of Book(1984) with every user.
# Out:
# array([1.        , 0.11013674, 0.0127091 , 0.        , 0.05618727,
#        0.03068486, 0.0874928 , 0.15837741, 0.03352553, 0.03769765,
#        0.07734131, 0.02289102, 0.10711257, 0.08534426, 0.11769018,
#        0.0557728 , 0.02587927, 0.12651909, 0.        , 0.14733114,
#        0.08388437, 0.07732577, 0.09389112, 0.        , 0.07642162,
#        0.14517437, 0.12847808, 0.01638712, 0.09117911, 0.05011953,
#        0.01653141, 0.10104308, 0.01975371, 0.0268319 , 0.0885619 ,
#        0.12161054, 0.06009405, 0.08965023, 0.01517732, 0.09520085,
#        0.05637857, 0.27779439, 0.10570014, 0.01038525, 0.09208417,
#        0.        , 0.04592574, 0.02005129, 0.        , 0.06136685,
#        0.00604602, 0.08465384, 0.05775924, 0.1985691 , 0.        ,
#        0.01346916, 0.03154015, 0.04679173, 0.08915014, 0.        ,
#        0.13920242, 0.06799777, 0.        , 0.11604696, 0.03040797,
#        0.05247255, 0.07067691, 0.12127148, 0.03442769, 0.01540805,
#        0.2660586 , 0.        , 0.10733528, 0.09150259, 0.03182853,
#        0.07643576, 0.        , 0.17184433, 0.03371911, 0.01161106,
#        0.02315884, 0.03079811, 0.02354807, 0.        , 0.05087004,
#        0.06517425, 0.01409486, 0.05608625, 0.05868766, 0.07098951,
#        0.02293094, 0.08172074, 0.01834054, 0.0169571 , 0.11557531,
#        0.17479853, 0.15946528, 0.06411221, 0.08866155, 0.0626556 ,
#        0.08506674, 0.04207216, 0.06349231, 0.03624645, 0.0394867 ,
#        0.0515041 , 0.01162238, 0.01806033, 0.07694006, 0.        ,
#        0.        , 0.        , 0.02952644, 0.03407569, 0.10252871,
#        0.        , 0.02478026, 0.02960888, 0.        , 0.        ,
#        0.02009356, 0.03227679, 0.02317792, 0.11375882, 0.02965917,
#        0.11405365, 0.10174488, 0.15275357, 0.01570753, 0.08932473,
#        0.00906821, 0.05374814, 0.        , 0.01411866, 0.04114861,
#        0.0768598 , 0.01338666, 0.02086884, 0.01613124, 0.1546981 ,
#        0.06818861, 0.02953902, 0.        , 0.15658   , 0.03849654,
#        0.        , 0.02017606, 0.23478454, 0.01558074, 0.1028289 ,
#        0.02347791, 0.02193227, 0.05550778, 0.08387877, 0.01166632,
#        0.03976337, 0.06161668, 0.        , 0.15448878, 0.02144119,
#        0.10648242, 0.10067234, 0.06794143, 0.09304639, 0.09565454,
#        0.02528702, 0.19117431, 0.05285139, 0.05397639, 0.11401113,
#        0.10766679, 0.06384661, 0.05746483, 0.03770721, 0.        ,
#        0.09681127, 0.06974098, 0.05509775, 0.13239972, 0.09230146,
#        0.13461528, 0.09029421, 0.08562932, 0.        , 0.03902994,
#        0.16543679, 0.04070925, 0.07927592, 0.10331757, 0.05770931,
#        0.07592049, 0.08144431, 0.03570785, 0.01673179, 0.02090211,
#        0.02532225, 0.        , 0.02284261, 0.06995879, 0.0223453 ,
#        0.12655653, 0.0883629 , 0.02240905, 0.        , 0.04949054,
#        0.08947746, 0.14475609, 0.01559893, 0.14427518, 0.0791893 ,
#        0.12409571, 0.05575706, 0.01726867, 0.02706376, 0.04950139,
#        0.02296101, 0.10979448, 0.14486065, 0.        , 0.06064408,
#        0.01949719, 0.        , 0.05285987, 0.03739746, 0.18128958,
#        0.09937455, 0.071373  , 0.03070886, 0.        , 0.09728841,
#        0.08424482, 0.05107612, 0.01556233, 0.02463426, 0.096999  ,
#        0.00935743, 0.03067719, 0.02125824, 0.02481376, 0.13233443,
#        0.        , 0.02551678, 0.07016206, 0.        , 0.06478974,
#        0.15111644, 0.02202624, 0.01295949, 0.04557405, 0.03209491,
#        0.03117223, 0.0702737 , 0.0890494 , 0.11881102, 0.12313034,
#        0.13819948, 0.10443096, 0.18159618, 0.07644963, 0.        ,
#        0.09647727, 0.01104658, 0.        , 0.09200764, 0.04273388,
#        0.20765297, 0.01778552, 0.03418939, 0.03482116, 0.10740511,
#        0.10935219, 0.01808751, 0.12999563, 0.10630975, 0.03761696,
#        0.08095393, 0.0912874 , 0.01954162, 0.02238144, 0.17662236,
#        0.        , 0.        , 0.01175271, 0.02213071, 0.        ,
#        0.0213464 , 0.01344947, 0.01033967, 0.01682586, 0.06867172,
#        0.10175725, 0.06324393, 0.06791346, 0.        , 0.02238144,
#        0.08062078, 0.18957795, 0.08078216, 0.        , 0.019556  ,
#        0.12187193, 0.10768412, 0.09145874, 0.09338304, 0.11716634,
#        0.        , 0.02423048, 0.06524361, 0.01982421, 0.06389736,
#        0.02227229, 0.10806625, 0.13970062, 0.        , 0.07088441,
#        0.10028578, 0.        , 0.02954704, 0.01706041, 0.06420676,
#        0.02155071, 0.0185177 , 0.12711729, 0.06648338, 0.14811756,
#        0.        , 0.0729493 , 0.        , 0.05922611, 0.02436918,
#        0.00903974, 0.07335084, 0.1115739 , 0.02685175, 0.        ,
#        0.0951636 , 0.01777824, 0.10711   , 0.        , 0.01878098,
#        0.        , 0.06028069, 0.1783604 , 0.14322371, 0.13131152,
#        0.02393919, 0.02042633, 0.01186345, 0.02739974, 0.01010278,
#        0.08977952, 0.02001225, 0.07220711, 0.02450074, 0.13180214,
#        0.10277325, 0.06532245, 0.02963342, 0.04625648, 0.05552673,
#        0.00900028, 0.10398757, 0.1101768 , 0.        , 0.13472424,
#        0.01912399, 0.02129699, 0.11972841, 0.1339112 , 0.1000778 ,
#        0.09676429, 0.06101924, 0.08257237, 0.05147342, 0.06991718,
#        0.0252089 , 0.07104829, 0.020678  , 0.04669322, 0.        ,
#        0.0561446 , 0.01418692, 0.        , 0.05225592, 0.08932969,
#        0.10822762, 0.01902994, 0.10196294, 0.08939814, 0.0039979 ,
#        0.06027318, 0.05974804, 0.        , 0.06422979, 0.11101507,
#        0.        , 0.08157177, 0.        , 0.14327716, 0.05717786,
#        0.17391754, 0.01892256, 0.05776177, 0.        , 0.0847733 ,
#        0.14174673, 0.00620667, 0.07580992, 0.05579718, 0.06314326,
#        0.05678602, 0.20711302, 0.11815113, 0.06957948, 0.06580312,
#        0.        , 0.        , 0.11815872, 0.04971139, 0.02132316,
#        0.        , 0.01370312, 0.22356342, 0.06494586, 0.04535604,
#        0.0286579 , 0.07805605, 0.05708181, 0.07254446, 0.01683487,
#        0.02896014, 0.02151889, 0.1442931 , 0.12512194, 0.09426108,
#        0.10686602, 0.12613202, 0.07740234, 0.04879375, 0.        ,
#        0.22552206, 0.02745658, 0.06160345, 0.2126727 , 0.06496271,
#        0.06597806, 0.02312855, 0.02781352, 0.06873563, 0.08121964,
#        0.08922442, 0.17958365, 0.08483338, 0.01233129, 0.09343123,
#        0.19255469, 0.08763217, 0.02021059, 0.1824324 , 0.23786513,
#        0.19734887, 0.061184  , 0.04248742, 0.07520489, 0.16088824,
#        0.23256741, 0.2020424 , 0.02460015, 0.15969038, 0.01705372,
#        0.05448494, 0.13242166, 0.15195163, 0.08802382, 0.02630335,
#        0.13305141, 0.01284413, 0.07574134, 0.03517224, 0.07394634,
#        0.02387728, 0.1605071 , 0.0965165 , 0.        , 0.        ,
#        0.02001156, 0.10277284, 0.05000965, 0.13396446, 0.01649152,
#        0.11443423, 0.06068084, 0.06595403, 0.06990948, 0.1517916 ,
#        0.        , 0.04768003, 0.02421716, 0.18270943, 0.01979733,
#        0.16871652, 0.        , 0.06733244, 0.08626422, 0.07783425,
#        0.06729079, 0.07787376, 0.17606666, 0.02759217, 0.01988047,
#        0.05589108, 0.05196132, 0.        , 0.12064258, 0.08639837,
#        0.14208058, 0.02370919, 0.07004159, 0.02260363, 0.04869051,
#        0.10813081, 0.1236551 , 0.02950629, 0.00178548, 0.10147988,
#        0.08492708, 0.02258122, 0.01714265, 0.02225656, 0.10491354,
#        0.0195985 , 0.19675855, 0.06210377, 0.2150064 , 0.06505999,
#        0.01551924, 0.10466572, 0.01174553, 0.11906083, 0.07986949,
#        0.08877812, 0.25062954, 0.01146213, 0.04958739, 0.15782083,
#        0.        , 0.14387479, 0.06964238, 0.15130125, 0.01833375,
#        0.09773047, 0.05653404, 0.19187723, 0.11996571, 0.04491848,
#        0.03943185, 0.02532121, 0.08063968, 0.03740485, 0.03091471,
#        0.02669956, 0.04587031, 0.15380592, 0.13777057, 0.01622923,
#        0.03145614, 0.02448826, 0.07597703, 0.09192314, 0.1674994 ,
#        0.07841535, 0.01228968, 0.11520946, 0.06453425, 0.10048626,
#        0.14899564, 0.06348371, 0.        , 0.02205355, 0.        ,
#        0.02040901, 0.        , 0.13764215, 0.09189302, 0.09637498,
#        0.00823495, 0.0837076 , 0.        , 0.04392382, 0.08922689,
#        0.08325867, 0.07565973, 0.01701   , 0.03838607, 0.05747133,
#        0.01171933, 0.01117662, 0.01049377, 0.0619086 , 0.01818944,
#        0.12447747, 0.07552261, 0.04645965])

# %% [markdown]
# The lesser the distance between two users higher their similarity score. Higher Similarity scores indicates that users are similar.

# %%
Pivot_df
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  249111  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             249628  249862  249894  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             250184  250405  250764  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [603 rows x 735 columns]

# %% [markdown]
# Finding index of a Book title.

# %%
import joblib 
joblib.dump(Similarity_scores,"Similarity_scores.pkl")
# Out:
# ['Similarity_scores.pkl']

# %%
import joblib
joblib.dump(Pivot_df,"User_Based.pkl")
# Out:
# ['User_Based.pkl']

# %%
book_titles = Pivot_df.index.tolist()

# %%
joblib.dump(book_titles,"Book-Titles.pkl")
# Out:
# ['Book-Titles.pkl']

# %%
import joblib
joblib.dump(Pivot_df['Book-Title'])

# %%
index1 = np.where(Pivot_df.index == 'Zoya')[0][0] 
index1
# Out:
# 601

# %% [markdown]
# Finding most similar books by their index.

# %%
similar_items1 = sorted(list(enumerate(Similarity_scores[1])),key = lambda x:x[1],reverse=True)[1:6]

# %%
similar_items1
# Out:
# [(34, 0.3209377366263928),
#  (254, 0.28373402266420134),
#  (299, 0.27903746938224816),
#  (30, 0.27401325075307853),
#  (569, 0.2685460935097372)]

# %% [markdown]
# Converting most similar book index to their respective names.

# %%
for i in similar_items1:
    print(Pivot_df.index[i[0]])
# Out:
# Along Came a Spider (Alex Cross Novels)
# Lightning
# On the Street Where You Live
# All Around the Town
# Violets Are Blue

# %%
def recommend(book_name):
    index = index = np.where(Pivot_df.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(Similarity_scores[index])),key = lambda x:x[1],reverse=True)[1:6]
    for i in similar_items:
        print(Pivot_df.index[i[0]])

# %%
recommend('The Lovely Bones: A Novel')
# Out:
# The Book of Ruth (Oprah's Book Club (Paperback))
# Good in Bed
# Life of Pi
# The Pilot's Wife : A Novel
# Where the Heart Is (Oprah's Book Club (Paperback))

# %%
recommend('The Two Towers (The Lord of the Rings, Part 2)')
# Out:
# The Fellowship of the Ring (The Lord of the Rings, Part 1)
# The Return of the King (The Lord of the Rings, Part 3)
# The Hobbit : The Enchanting Prelude to The Lord of the Rings
# It Was on Fire When I Lay Down on It
# Harry Potter and the Prisoner of Azkaban (Book 3)

# %%
recommend("1984")
# Out:
# Animal Farm
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Handmaid's Tale
# Fahrenheit 451

# %% [markdown]
# ## As we can see our recommendation system is working really good.
